# %% [markdown]
# # SMOKE_LAYER_A
# Seeds + run card via `methodology_preamble` (caps from `runs/smoke.yaml`).
# Heavy statistics stay in pytest (`tests/test_layer_a_permutation_smoke.py`).

# %%
from methodology_preamble import init_notebook, build_run_card, assert_run_card

info = init_notebook()
rc = build_run_card(
    run_id="nb_smoke_layer_a",
    hypothesis="Notebook smoke: preamble + run card wiring",
    metric="n/a (see pytest for permutation p-value)",
    null="y_shuffle (implemented in tests)",
    truth_scope="CI / local smoke only",
    seed=info["seed"],
)
assert_run_card(rc)
info["methodology_caps"]
