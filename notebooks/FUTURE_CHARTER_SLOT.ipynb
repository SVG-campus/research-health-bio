# %% [markdown]
# # FUTURE_CHARTER_SLOT
# Enabled **future charter** notebook: pre-registered study validation slot.
# Runs in CI to ensure reproducibility and truth scope controls.

# %%
from methodology_preamble import init_notebook, build_run_card, assert_run_card

info = init_notebook()
rc = build_run_card(
    run_id="future_charter_slot_validation",
    hypothesis="Future charter slot validation: verified under OCCA framework",
    metric="mutual_information",
    null="phase_shuffled_spectral_mc",
    truth_scope="ECT-2026 pre-registration baseline",
    seed=info["seed"],
)
assert_run_card(rc)
"future_charter_slot_ok"
