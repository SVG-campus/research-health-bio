# %% [markdown]
# # SMOKE_IMPORTS
# Fast sanity: repo layout + `methodology_preamble` import (CI kernel cwd may be `notebooks/`).

# %%
from pathlib import Path

here = Path.cwd()
root = here if (here / "METHODS.md").is_file() else here.parent
assert (root / "METHODS.md").is_file(), "METHODS.md missing"
assert (root / "runs" / "smoke.yaml").is_file(), "smoke.yaml missing"

from methodology_preamble import init_notebook

init_notebook()
"imports_ok"
