# %% [markdown]
# # CHARTER_SHELL
# Minimal **charter-shaped** notebook: preamble + run card only (no heavy Layer A).
# Listed in `runs/ci_notebooks.yaml` with `enabled: false` until a real charter run is ready for CI.

# %%
from methodology_preamble import init_notebook, build_run_card, assert_run_card

info = init_notebook()
rc = build_run_card(
    run_id="charter_shell_template",
    hypothesis="Charter shell: extend cells before enabling this row in ci_notebooks.yaml",
    metric="n/a (template)",
    null="n/a",
    truth_scope="CI template only",
    seed=info["seed"],
)
assert_run_card(rc)
"charter_shell_ok"
